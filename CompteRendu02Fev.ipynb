# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np
import cv2


img = cv2.imread('../img/facedetecImg.jpg')

face_cascade = cv2.CascadeClassifier('../haarcascade_frontalface_default.xml')
eye_cascade = cv2.CascadeClassifier('../haarcascade_eye.xml')
img_exo = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
gray = cv2.cvtColor(img_exo, cv2.COLOR_RGB2GRAY)



faces = face_cascade.detectMultiScale(gray, 1.3, 5)

# %%
faces
# Out:
# array([[ 22,  27,  72,  72],
#        [253,  19,  76,  76],
#        [128,  31,  79,  79]], dtype=int32)

# %%
plt.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB)) 
for (x,y,w,h) in faces:
    cv2.rectangle(img,(x,y),(x+w,y+h),(255,0,0),2)
    roi_gray = gray[y:y+h, x:x+w]
    roi_color = img[y:y+h, x:x+w]
    eyes = eye_cascade.detectMultiScale(roi_gray)
    for (ex,ey,ew,eh) in eyes:
        cv2.rectangle(roi_color,(ex,ey),(ex+ew,ey+eh),(0,255,0),2)

# %%
cv2.rectangle(img,(x,y),(x+w,y+h),(255,0,0),2)
# Out:
# array([[[184, 193, 192],
#         [181, 190, 189],
#         [181, 190, 189],
#         ...,
#         [234, 242, 244],
#         [231, 241, 242],
#         [227, 237, 238]],
#
#        [[181, 190, 189],
#         [181, 190, 189],
#         [182, 191, 190],
#         ...,
#         [234, 242, 244],
#         [233, 243, 244],
#         [231, 241, 242]],
#
#        [[182, 191, 190],
#         [183, 192, 191],
#         [184, 193, 192],
#         ...,
#         [234, 242, 244],
#         [235, 243, 245],
#         [234, 244, 245]],
#
#        ...,
#
#        [[ 38,  41,  48],
#         [ 32,  33,  38],
#         [ 17,  16,  21],
#         ...,
#         [ 74,  83,  90],
#         [ 73,  82,  89],
#         [ 72,  81,  88]],
#
#        [[ 38,  41,  48],
#         [ 31,  32,  37],
#         [ 13,  12,  17],
#         ...,
#         [ 74,  83,  92],
#         [ 72,  81,  90],
#         [ 71,  80,  89]],
#
#        [[ 38,  41,  48],
#         [ 31,  32,  37],
#         [ 10,   9,  14],
#         ...,
#         [ 81,  90,  99],
#         [ 77,  86,  95],
#         [ 74,  83,  92]]], dtype=uint8)

# %%
import numpy as np
import cv2

cap = cv2.VideoCapture(0)

while(True):
    # Capture frame-by-frame
    ret, frame = cap.read()

    # Our operations on the frame come here
    gray = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)

    # Display the resulting frame
    plt.imshow('frame',gray)
    if cv2.waitKey(1) & 0xFF == ord('q'):
        break

# When everything done, release the capture
cap.release()
cv2.destroyAllWindows()
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# <ipython-input-19-3e7a15043458> in <module>()
#       9
#      10     # Our operations on the frame come here
# ---> 11     gray = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)
#      12
#      13     # Display the resulting frame
#
# error: /tmp/build/80754af9/opencv_1512687413662/work/modules/imgproc/src/color.cpp:11048: error: (-215) scn == 3 || scn == 4 in function cvtColor
